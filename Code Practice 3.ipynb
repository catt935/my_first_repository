# %% [markdown]
# # Catherine Kim, Code Practice 3

# %% [markdown]
# ## **Question 1**

# %%
import pandas as pd
data = {'BRA': [13.37, 13.30, 14.34, 15.07, 15.46, 15.98, 16.10],
        'JPN': [33.43, 31.83, 33.71, 34.29, 35.60, 36.79, 37.39],
        'USA': [48.30, 46.91, 48.31, 49.72, 51.41, 52.94, 54.60],
        'Year': [2008, 2009, 2010, 2011, 2012, 2013, 2014]}
weo = pd.DataFrame(data)

# %%
print(weo)
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# **a)** The import statement imports the panda package and all the functions included in it into my jupyter notebook so I can use the code without having to write it first

# %%
type(data)
# Out:
# dict

# %% [markdown]
# **b)** dictionary

# %% [markdown]
# **c)** So that Jupyter knows I'm calling the DataFrame function from pandas, which I imported earlier as pd

# %%
type(weo)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **d)** pandas.core.frame.DataFrame

# %%
weo.shape
# Out:
# (7, 4)

# %% [markdown]
# **e)** weo has 7 rows and 4 columns

# %%
weo.dtypes
# Out:
# BRA     float64
# JPN     float64
# USA     float64
# Year      int64
# dtype: object

# %% [markdown]
# **f)** The first 3 dolumns are floats but the last is an integer, thus the total dtype of columns is object because there's two or more different types

# %%
print(weo['Year'])
print(type(weo['Year']))
# Out:
# 0    2008
# 1    2009
# 2    2010
# 3    2011
# 4    2012
# 5    2013
# 6    2014
# Name: Year, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
weo[['Year']]
# Out:
#    Year
# 0  2008
# 1  2009
# 2  2010
# 3  2011
# 4  2012
# 5  2013
# 6  2014

# %%
print(type(weo[['Year']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(weo[[3]])
print(type(weo[[3]]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-82e5c946ed15> in <module>()
# ----> 1 print(weo[[3]])
#       2 print(type(weo[[3]]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...

# %% [markdown]
# **g)** weo['Year'] pulls the column of data of year and is a series;
# weo[['Year']] formats that information and makes it a data frame;
# weo[[3]] returns an error

# %%
weo['Year'].astype(float)
# Out:
# 0    2008.0
# 1    2009.0
# 2    2010.0
# 3    2011.0
# 4    2012.0
# 5    2013.0
# 6    2014.0
# Name: Year, dtype: float64

# %% [markdown]
# **h)** astype

# %%
t=weo.tail(3)
print(t)
print(type(t))
# Out:
#      BRA    JPN    USA  Year
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# **i)** The result of tail(3) is that it takes the last 3 rows of information and displays them in a new data frame. t is a data frame and it looks like weo just with less information.

# %%
h=weo.head(4)
print(h)
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011

# %% [markdown]
# **j)** weo.head(4)

# %%
type(weo['BRA'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **k)** it is a series

# %% [markdown]
# **l)** weo["BRAJPN_Ratio"] = weo['BRA']/weo['JPN']

# %%
weo["BRAJPN_Ratio"] = weo['BRA']/weo['JPN']
print(weo)
# Out:
#      BRA    JPN    USA  Year  BRAJPN_Ratio
# 0  13.37  33.43  48.30  2008      0.399940
# 1  13.30  31.83  46.91  2009      0.417845
# 2  14.34  33.71  48.31  2010      0.425393
# 3  15.07  34.29  49.72  2011      0.439487
# 4  15.46  35.60  51.41  2012      0.434270
# 5  15.98  36.79  52.94  2013      0.434357
# 6  16.10  37.39  54.60  2014      0.430596

# %% [markdown]
# **m)** weo.drop(columns=['BRAJAP_Ratio'], inplace = True)

# %%
weo.drop(columns=['BRAJPN_Ratio'], inplace = True)
print(weo)
# Out:
#      BRA    JPN    USA  Year
# 0  13.37  33.43  48.30  2008
# 1  13.30  31.83  46.91  2009
# 2  14.34  33.71  48.31  2010
# 3  15.07  34.29  49.72  2011
# 4  15.46  35.60  51.41  2012
# 5  15.98  36.79  52.94  2013
# 6  16.10  37.39  54.60  2014

# %% [markdown]
# **n)** The row titles are just the sequential numbers from 0 to 6 and the column titles are the names of the countries and the word year

# %%
weo.set_index('Year', inplace = True)
print(weo)
# Out:
#         BRA    JPN    USA
# Year
# 2008  13.37  33.43  48.30
# 2009  13.30  31.83  46.91
# 2010  14.34  33.71  48.31
# 2011  15.07  34.29  49.72
# 2012  15.46  35.60  51.41
# 2013  15.98  36.79  52.94
# 2014  16.10  37.39  54.60

# %% [markdown]
# **o)** weo.set_index('Year', inplace = True)

# %%
weo.columns = ['Brazil','Japan','United States']
print(weo)
# Out:
#       Brazil  Japan  United States
# Year
# 2008   13.37  33.43          48.30
# 2009   13.30  31.83          46.91
# 2010   14.34  33.71          48.31
# 2011   15.07  34.29          49.72
# 2012   15.46  35.60          51.41
# 2013   15.98  36.79          52.94
# 2014   16.10  37.39          54.60

# %% [markdown]
# **p)** weo.columns = ['Brazil','Japan','United States']

# %%
weo.to_excel("weo.xlsx")

# %% [markdown]
# **q)** use the .to_excel method: weo.to_excel("weo.xlsx")

# %%
weo.mean()
# Out:
# Brazil           14.802857
# Japan            34.720000
# United States    50.312857
# dtype: float64

# %% [markdown]
# **r)** uset .mean- weo.mean(). Brazil's mean is 14.408, Japan's mean is 34.72, US's mean is 50.31

# %%
weo.mean(axis=1)
# Out:
# Year
# 2008    31.700000
# 2009    30.680000
# 2010    32.120000
# 2011    33.026667
# 2012    34.156667
# 2013    35.236667
# 2014    36.030000
# dtype: float64

# %% [markdown]
# **s)** use weo.mean(axis=1) to get the mean of each row rather than the columns

# %% [markdown]
# **t)** (below)

# %%
weo.plot()

# %% [markdown]
# **u)** (below)

# %%
weo.plot(color=['green','red','blue'])

# %%
weo.plot?

# %% [markdown]
# **v)** (below)

# %%
weo.plot(logy = True, color = ['green','red','blue'])

# %% [markdown]
# **w)** (below)

# %%
weo['Brazil'].plot()

# %% [markdown]
# ## **Question 2**

# %%
url = "https://raw.githubusercontent.com/NYUDataBootcamp/Materials/master/Data/entry_poll_fall16.csv"

# %% [markdown]
# **a)** (below)

# %%
ep = pd.read_csv(url)
ep
# Out:
#               TimeStamp            Why have you enrolled in this course?    \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %% [markdown]
# **b)** It's a multiple choice survey as to why students took the classes, how much experience they had with the class material beforehand, major, expected career etc. The variables are the different questions and the responses are the various options that students could have chosen

# %%
ep.dtypes
# Out:
# TimeStamp                                                                                              object
# Why have you enrolled in this course?                                                                  object
# What program are you enrolled in?                                                                      object
# How much programming experience have you had?                                                          object
# How much experience with probability and statistics have you had?                                      object
# What is your expected major or concentration?                                                          object
# What career path most interests you?                                                                   object
# Do you use social media for information purposes?  Check all that apply.                               object
# ...

# %% [markdown]
# **c)** The type of the variables is "object"

# %% [markdown]
# **d)** (below)

# %%
ep.columns= ['Time','Why','Program','Code Experience','Stats Experience','Major','Career','Soc Media','Data Interests','Class Interests']
ep
# Out:
#                    Time                                                Why  \
# 0   2016-08-16 12:55:02                             To help with my career
# 1   2016-08-31 05:54:00                                 I heard it was fun
# 2   2016-09-01 19:43:56                                 I like a challenge
# 3   2016-09-01 20:00:08                                 I heard it was fun
# 4   2016-09-01 20:00:52                                 I heard it was fun
# 5   2016-09-01 20:56:31                                 I heard it was fun
# 6   2016-09-01 22:30:33                             To help with my career
# 7   2016-09-01 22:31:14                             To help with my career
# 8   2016-09-02 01:09:15                        I lost my mind for a minute
# 9   2016-09-02 10:25:48                                 I heard it was fun
# 10  2016-09-02 11:54:33                             To help with my career
# ...

# %%
ep[list(ep)[1]].value_counts()
# Out:
# To help with my career                               60
# I heard it was fun                                   14
# I lost my mind for a minute                           5
# I code/build websites in my spare time as a hobby     1
# I like a challenge                                    1
# Recommended by a professor.                           1
# i am living in Santiago de Chile                      1
# Wanted to try something completely different          1
# To finish my major                                    1
# Name: Why, dtype: int64

# %% [markdown]
# **e)** This code counts all the values of the first variable (ie the question "Why did you take this course?"). Supposedly teh value_counts command is the function that will tally how many times each unique value showed up.

# %% [markdown]
# ## **Question 3**

# %%
url1 = 'https://raw.githubusercontent.com/fivethirtyeight/data/master/'
url2 = 'college-majors/recent-grads.csv'
url = url1 + url2

# %%
df538 = pd.read_csv(url)
df538.shape
# Out:
# (173, 21)

# %%
df538
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %% [markdown]
# **a)** Use pd.read_csv(url) to create a dataframe via pandas from the url. The dimensions are 173x21

# %%
df538.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %% [markdown]
# **b)** we would use the .head(10) command

# %%
print(df538.columns[2])
print(df538.columns[4])
print(df538.columns[15])
print(df538.columns[16])
print(df538.columns[17])
# Out:
# Major
# Men
# Median
# P25th
# P75th

# %% [markdown]
# **c)** The names of the variables are "major", "men", "median", "P25", and "P75". Major represents the name of the major, men represents how many men are in that major, median represents presumably the median salary while P25 and P75 represent the 25th and 75th percentiles respectively of earned salaries

# %% [markdown]
# **d)** (below)

# %%
df538.set_index("Major", inplace = True)

# %%
df538
# Out:
#                                                Rank  Major_code     Total  \
# Major
# PETROLEUM ENGINEERING                             1        2419    2339.0
# MINING AND MINERAL ENGINEERING                    2        2416     756.0
# METALLURGICAL ENGINEERING                         3        2415     856.0
# NAVAL ARCHITECTURE AND MARINE ENGINEERING         4        2417    1258.0
# CHEMICAL ENGINEERING                              5        2405   32260.0
# NUCLEAR ENGINEERING                               6        2418    2573.0
# ACTUARIAL SCIENCE                                 7        6202    3777.0
# ASTRONOMY AND ASTROPHYSICS                        8        5001    1792.0
# MECHANICAL ENGINEERING                            9        2414   91227.0
# ELECTRICAL ENGINEERING                           10        2408   81527.0
# COMPUTER ENGINEERING                             11        2407   41542.0
# AEROSPACE ENGINEERING                            12        2401   15058.0
# ...

# %% [markdown]
# **e)** (below)

# %%
df538.sort_values("Total",ascending=False,inplace=True)

# %%
df538
# Out:
#                                                     Rank  Major_code  \
# Major
# PSYCHOLOGY                                           146        5200
# BUSINESS MANAGEMENT AND ADMINISTRATION                77        6203
# BIOLOGY                                              124        3600
# GENERAL BUSINESS                                      58        6200
# COMMUNICATIONS                                        94        1901
# NURSING                                               35        6107
# MARKETING AND MARKETING RESEARCH                      78        6206
# ACCOUNTING                                            41        6201
# ENGLISH LANGUAGE AND LITERATURE                      138        3301
# POLITICAL SCIENCE AND GOVERNMENT                      79        5506
# FINANCE                                               36        6207
# ELEMENTARY EDUCATION                                 139        2304
# ...

# %% [markdown]
# **f)** Because we sorted the dataframe by total in the previous question, we just have to pull the top 10 entries, thus we can use the .head(10) method

# %%
df538.head(10)
# Out:
#                                         Rank  Major_code     Total       Men  \
# Major
# PSYCHOLOGY                               146        5200  393735.0   86648.0
# BUSINESS MANAGEMENT AND ADMINISTRATION    77        6203  329927.0  173809.0
# BIOLOGY                                  124        3600  280709.0  111762.0
# GENERAL BUSINESS                          58        6200  234590.0  132238.0
# COMMUNICATIONS                            94        1901  213996.0   70619.0
# NURSING                                   35        6107  209394.0   21773.0
# MARKETING AND MARKETING RESEARCH          78        6206  205211.0   78857.0
# ACCOUNTING                                41        6201  198633.0   94519.0
# ENGLISH LANGUAGE AND LITERATURE          138        3301  194673.0   58227.0
# POLITICAL SCIENCE AND GOVERNMENT          79        5506  182621.0   93880.0
#
#                                            Women               Major_category  \
# Major
# ...

# %% [markdown]
# **g)** (below)

# %%
df538.head(10)["Median"].sort_values().plot(kind = "barh")

# %%
df538.head(10)["P25th"].sort_values().plot(kind = "barh")
